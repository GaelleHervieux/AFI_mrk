# %% [markdown]
# ##
# Colorado
# Plots Comparisons
# Tensor elevation + cell

# %%
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import scipy
import cftime
import cartopy
import cartopy.crs as ccrs
import matplotlib.colors as colors
import cmaps
from xhistogram.xarray import histogram
from statsmodels.nonparametric.smoothers_lowess import lowess as  sm_lowess
from copy import copy
import geopandas as gpd
from shapely.geometry import Point

# %%
state_borders =\
cartopy.feature.NaturalEarthFeature(category='cultural',\
        name='admin_1_states_provinces_lakes', scale='50m', facecolor='none')

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # READ EVGAM output FILES

# %%
yearb=1941
yeare=2025

lon_min = 250.5
lon_max = 257
lat_min = 31.
lat_max = 37

dirin ='/Users/ghervieux/AFI'

ds0 = xr.open_dataset(f'{dirin}/NorthAmerica_ij_extremes_gev_1941_2025.nc')
ds0 = ds0.sel(lon=slice(lon_min,lon_max),lat=slice(lat_min,lat_max))
rl1000 = ds0['rl100']
loc0 = ds0['location'] 
scale0 = ds0['scale'] 
shape0 = ds0['shape'] 

ds1 = xr.open_dataset(f'{dirin}/NewMexico_DJFtas_cr10_mrf50_glostmrf12_loc_sc_sh_1941_2025.nc')
rl1001 = ds1['rl100'] 
loc1 = ds1['location'] 
scale1 = ds1['scale'] 
shape1 = ds1['shape'] 

units = 'degree-days (°C)'

Tlabels = ['extRemes (independent)','Evgam (space + time covariates)']

# %% [markdown]
# ##
# Evgam :    covariates: Mean Winter Temperature (DJFtas), Global Land and Ocean Average Temperature Anomalies (GLOST)
#
# formula_gev <- list(AFI
#
# ~ s(DJFtas,bs="cr",k=10) + s(cell,k=50, bs="mrf", xt = list(nb = nb)) + s(cell,k=12, bs="mrf", xt = list(nb = nb),by=glost) ,
#
# ~ s(DJFtas,bs="cr",k=10) + s(cell,k=50, bs="mrf", xt = list(nb = nb)) + s(cell,k=12, bs="mrf", xt = list(nb = nb),by=glost) ,
#
# ~ s(DJFtas,bs='cr',k=10) + s(cell,k=50, bs="mrf", xt = list(nb = nb)) )

# %%
rl1000 = rl1000.expand_dims({'time':ds1['time']})
loc0 = loc0.expand_dims({'time':ds1['time']})
scale0 = scale0.expand_dims({'time':ds1['time']})
shape0 = shape0.expand_dims({'time':ds1['time']})

# %%
Trl100 = [rl1000.where(rl1000!=-99999.), rl1001]
Tloc = [loc0.where(loc0!=-99999.), loc1]
Tscale = [scale0.where(scale0!=-99999.), scale1]
Tshape = [shape0.where(shape0!=-99999.), shape1]

# %%
dshgt = xr.open_dataset('/Users/ghervieux/AFI/hgt.sfc.era5.1.nc')
dshgt = dshgt.sortby('lat')
dshgt = dshgt.isel(time=0, drop=True)

# %% [markdown]
# # Reduce domain for testing purpose

# %%
dshgt = xr.open_dataset('/Users/ghervieux/AFI/hgt.sfc.era5.1.nc')
dshgt = dshgt.sortby('lat')
dshgt = dshgt.isel(time=0, drop=True)
dshgt = dshgt.sel(lon=slice(lon_min,lon_max),lat=slice(lat_min,lat_max))
elevation = dshgt['hgt']

# %%
proj=ccrs.PlateCarree()

fig, ax = plt.subplots(nrows=1,ncols=1,figsize=(9,9),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.2,left=0.1, right=0.9,top=0.95,hspace=0.01,wspace=0.01)
cc = elevation.plot.pcolormesh(ax=ax,cmap='gist_earth',levels=np.arange(0,3000,50))
####
grd = ax.gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')

ax.set_xlabel('')
ax.set_ylabel('')
ax.add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
ax.tick_params(axis='both',direction='out',width=1.5,length=4)
ax.add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
ax.coastlines()
ax.set_xticks(ax.get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
ax.set_xticklabels([f'{round(ixx+360)}$\\degree$E' for ixx in ax.get_xticks()],size=18)
ax.set_yticks(ax.get_yticks()[1:-1],crs=ccrs.PlateCarree())
ax.set_yticklabels([f'{round(ixx)}$\\degree$N' for ixx in ax.get_yticks()],size=18)
# Out:
# [Text(0, 31.0, '31$\\degree$N'),
#  Text(0, 32.0, '32$\\degree$N'),
#  Text(0, 33.0, '33$\\degree$N'),
#  Text(0, 34.0, '34$\\degree$N'),
#  Text(0, 35.0, '35$\\degree$N'),
#  Text(0, 36.0, '36$\\degree$N'),
#  Text(0, 37.0, '37$\\degree$N')]

# %% [markdown]
# # PLOT Return Level 100

# %%
proj=ccrs.PlateCarree()

fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,9),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.2,left=0.1, right=0.9,top=0.95,hspace=0.01,wspace=0.03)
ax = ax.flatten()
for ix in range(0,2):
  cc = Trl100[ix].sel(time=yearb).plot.pcolormesh(ax=ax[ix],cmap='turbo',levels=np.arange(20,1500,20),add_colorbar=False)
  ####
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')

  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

ax[0].set_yticks(ax[0].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
ax[0].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[0].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label=f'{units}',fontsize=16)
plt.suptitle(f'Return Level 100year, year={yearb}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Return Level 100year, year=1941')

# %%
proj=ccrs.PlateCarree()

fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,9),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.2,left=0.1, right=0.9,top=0.95,hspace=0.01,wspace=0.03)
ax = ax.flatten()
for ix in range(0,2):
  cc = Trl100[ix].sel(time=yeare).plot.pcolormesh(ax=ax[ix],cmap='turbo',levels=np.arange(20,1500,20),add_colorbar=False)
  ####
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')

  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

ax[0].set_yticks(ax[0].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
ax[0].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[0].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label=f'{units}',fontsize=16)
plt.suptitle(f'Return Level 100year, year={yeare}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Return Level 100year, year=2025')

# %%
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,9),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.2,left=0.1, right=0.9,top=0.95,hspace=0.01,wspace=0.03)
ax = ax.flatten()
for ix in range(0,2):
  cc = Tloc[ix].sel(time=yearb).plot.pcolormesh(ax=ax[ix],cmap='turbo',levels=np.arange(0,1020,20),add_colorbar=False)
  ####
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')

  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

ax[0].set_yticks(ax[0].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
ax[0].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[0].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label=f'',fontsize=16)
plt.suptitle(f'Location parameter, year={yearb}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Location parameter, year=1941')

# %%
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,9),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.2,left=0.1, right=0.9,top=0.95,hspace=0.01,wspace=0.03)
ax = ax.flatten()
for ix in range(1,-1,-1):
  cc = Tloc[ix].sel(time=yeare).plot.pcolormesh(ax=ax[ix],cmap='turbo',levels=np.arange(0,1020,20),add_colorbar=False)
  ####
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')

  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

ax[0].set_yticks(ax[0].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
ax[0].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[0].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label=f'',fontsize=16)
plt.suptitle(f'Location parameter, year={yeare}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Location parameter, year=2025')

# %%
proj=ccrs.PlateCarree()
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,9),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.2,left=0.1, right=0.9,top=0.95,hspace=0.01,wspace=0.03)
ax = ax.flatten()
for ix in range(0,2):
  cc = Tscale[ix].sel(time=yearb).plot.pcolormesh(ax=ax[ix],cmap='turbo',levels=np.arange(0,480,20),add_colorbar=False)
  ####
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')

  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

ax[0].set_yticks(ax[0].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
ax[0].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[0].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label=f'',fontsize=16)
plt.suptitle(f'Scale parameter, year={yearb}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Scale parameter, year=1941')

# %%
proj=ccrs.PlateCarree()
fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,9),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.2,left=0.1, right=0.9,top=0.95,hspace=0.01,wspace=0.03)
ax = ax.flatten()
for ix in range(0,2):
  cc = Tscale[ix].sel(time=yeare).plot.pcolormesh(ax=ax[ix],cmap='turbo',levels=np.arange(0,480,20),add_colorbar=False)
  ####
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')

  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

ax[0].set_yticks(ax[0].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
ax[0].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[0].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label=f'',fontsize=16)
plt.suptitle(f'Scale parameter, year={yeare}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Scale parameter, year=2025')

# %%
proj=ccrs.PlateCarree()

fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,9),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.2,left=0.1, right=0.9,top=0.95,hspace=0.01,wspace=0.03)
ax = ax.flatten()
for ix in range(0,2):
  cc = Tshape[ix].sel(time=yearb).plot.pcolormesh(ax=ax[ix],cmap=cmaps.ncl_default,levels=np.arange(-1.2,1.3,0.1),add_colorbar=False)
  ####
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')

  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

ax[0].set_yticks(ax[0].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
ax[0].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[0].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label=f'',fontsize=16)
plt.suptitle(f'Shape parameter, year={yearb}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Shape parameter, year=1941')

# %%
proj=ccrs.PlateCarree()

fig, ax = plt.subplots(nrows=1,ncols=2,figsize=(14,9),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.2,left=0.1, right=0.9,top=0.95,hspace=0.01,wspace=0.03)
ax = ax.flatten()
for ix in range(0,2):
  cc = Tshape[ix].sel(time=yeare).plot.pcolormesh(ax=ax[ix],cmap=cmaps.ncl_default,levels=np.arange(-1.2,1.3,0.1),add_colorbar=False)
  ####
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')

  ax[ix].set_title(f'{Tlabels[ix]}',fontsize=18)  
  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()

ax[0].set_yticks(ax[0].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
ax[0].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[0].get_yticks()],size=14)
#
ax_cbar = fig.add_axes([0.2, 0.2, 0.6, 0.02])
cbar=fig.colorbar(cc,cax=ax_cbar,shrink=0.5,orientation='horizontal')
cbar.ax.tick_params(labelsize=14)  
cbar.set_label(label=f'',fontsize=16)
plt.suptitle(f'Shape parameter, year={yeare}',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Shape parameter, year=2025')

# %%
it=0

fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(14,11),subplot_kw={'projection':proj})
plt.subplots_adjust(bottom=0.1,left=0.1, right=0.9,wspace=.2,hspace=0.,top=0.95)
ax = ax.flatten()
Trl100[it].sel(time=iyear).plot.pcolormesh(ax=ax[0],cmap='turbo',levels=np.arange(0,1500,50),cbar_kwargs={'label':units,'shrink':0.6})
ax[0].set_title(f'Return Level 100year',fontsize=18)  
Tloc[it].sel(time=iyear).plot.pcolormesh(ax=ax[1],cmap='turbo',levels=np.arange(0,1000,50),cbar_kwargs={'label':'','shrink':0.6})
ax[1].set_title(f'Location parameter',fontsize=18)  
Tscale[it].sel(time=iyear).plot.pcolormesh(ax=ax[2],cmap='turbo',levels=np.arange(0,220,10),cbar_kwargs={'label':'','shrink':0.6})
ax[2].set_title(f'Scale parameter',fontsize=18)  
Tshape[it].sel(time=iyear).plot.pcolormesh(ax=ax[3],cmap=cmaps.ncl_default,levels=np.arange(-1.5,1.6,0.1),cbar_kwargs={'label':'','shrink':0.6})
ax[3].set_title(f'Shape parameter',fontsize=18)  
####
for ix in range(0,4): 
  grd = ax[ix].gridlines(
    draw_labels=False, 
    color='gray', alpha=0.01, linestyle='--')

  ax[ix].set_xlabel('')
  ax[ix].set_ylabel('')
  ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
  ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
  ax[ix].set_yticks(ax[ix].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[ix].get_yticks()],size=14)
  ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
  ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
  ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
  ax[ix].coastlines()
#
plt.suptitle(f'{Tlabels[it]}',fontsize=20)  
plt.show()

# %%
Tyears = [1944,1964,1984,2004,2024]
it = 1
proj=ccrs.PlateCarree()

for iyear in Tyears:

  fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(14,12),subplot_kw={'projection':proj})
  plt.subplots_adjust(bottom=0.1,left=0.1, right=0.9,wspace=.2,hspace=0.,top=0.95)
  ax = ax.flatten()
  Trl100[it].sel(time=iyear).plot.pcolormesh(ax=ax[0],cmap='turbo',levels=np.arange(0,1500,50),cbar_kwargs={'label':units,'shrink':0.6})
  ax[0].set_title(f'Return Level 100year',fontsize=18)  
  Tloc[it].sel(time=iyear).plot.pcolormesh(ax=ax[1],cmap='turbo',levels=np.arange(0,700,50),cbar_kwargs={'label':'','shrink':0.6})
  ax[1].set_title(f'Location parameter',fontsize=18)  
  Tscale[it].sel(time=iyear).plot.pcolormesh(ax=ax[2],cmap='turbo',levels=np.arange(0,440,20),cbar_kwargs={'label':'','shrink':0.6})
  ax[2].set_title(f'Scale parameter',fontsize=18)  
  Tshape[it].sel(time=iyear).plot.pcolormesh(ax=ax[3],cmap=cmaps.ncl_default,levels=np.arange(-1.2,1.3,0.1),cbar_kwargs={'label':'','shrink':0.6})
  ax[3].set_title(f'Shape parameter',fontsize=18)  
  ####
  for ix in range(0,4): 
    grd = ax[ix].gridlines(
        draw_labels=False, 
        color='gray', alpha=0.01, linestyle='--')

    ax[ix].set_xlabel('')
    ax[ix].set_ylabel('')
    ax[ix].add_feature(state_borders,zorder=100,linewidth=0.4,edgecolor='k')
    ax[ix].tick_params(axis='both',direction='out',width=1.5,length=4)
    ax[ix].set_yticks(ax[ix].get_yticks()[1:-1:2],crs=ccrs.PlateCarree())
    ax[ix].set_yticklabels([f'{round(ixx)}$\degree$N' for ixx in ax[ix].get_yticks()],size=14)
    ax[ix].set_xticks(ax[ix].get_xticks()[1:-1:2],crs=ccrs.PlateCarree())
    ax[ix].set_xticklabels([f'{round(ixx)}$\degree$W' for ixx in ax[ix].get_xticks()],size=14)
    ax[ix].add_feature(state_borders,zorder=100,edgecolor='k',linewidth=0.15) 
    ax[ix].coastlines()
  #
  plt.suptitle(f'{Tlabels[it]}, year={iyear}',fontsize=20)  
  plt.show()
